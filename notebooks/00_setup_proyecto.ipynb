# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/tfm_visnu_raw/raw/")
dbutils.fs.mkdirs("/Volumes/workspace/default/tfm_visnu_raw/clean/")
dbutils.fs.mkdirs("/Volumes/workspace/default/tfm_visnu_raw/preprocess/")
dbutils.fs.mkdirs("/Volumes/workspace/default/tfm_visnu_raw/models/")
dbutils.fs.mkdirs("/Volumes/workspace/default/tfm_visnu_raw/exports/")
# Out:
# True
